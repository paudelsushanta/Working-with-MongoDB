# %%
# Importing all the necessary libraries
import numpy as np
import pandas as pd
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Connecting to the MongoDatabase
client=MongoClient("mongodb+srv://sushant:12345@cluster0.c1muvlt.mongodb.net/?retryWrites=true&w=majority")

# %%
# Accessing our collection
mydb=client.cluster0
mycollection=mydb.blog

# %%
mycollection.find({})

# %% [markdown]
# #### $group

# %%
pipeline=[{
    '$group':
        {    
            '_id':{'genre':'$genre'},
             'count': {'$sum': 1}
        }
    },
    {'$sort': {'count': -1}},
    
                                                                                                                                                                                                                                                                          
  ]
          
          
pprint.pprint(list(client.cluster0.blog.aggregate(pipeline)))
# Out:
# [{'_id': {'genre': 'Drama'}, 'count': 5455},
#  {'_id': {'genre': 'Comedy'}, 'count': 3275},
#  {'_id': {'genre': 'Documentary'}, 'count': 2047},
#  {'_id': {'genre': 'Comedy, Drama'}, 'count': 1643},
#  {'_id': {'genre': 'Drama, Romance'}, 'count': 1392},
#  {'_id': {'genre': 'Comedy, Romance'}, 'count': 1065},
#  {'_id': {'genre': 'Comedy, Drama, Romance'}, 'count': 1053},
#  {'_id': {'genre': 'Horror'}, 'count': 931},
#  {'_id': {'genre': 'Crime, Drama'}, 'count': 626},
#  {'_id': {'genre': 'Drama, Thriller'}, 'count': 602}]

# %%
pipeline=[{
    
    '$sortByCount':'$genre'
},
    {'$limit': 10}
]

pprint.pprint(list(client.cluster0.blog.aggregate(pipeline)))
# Out:
# [{'_id': 'Drama', 'count': 5455},
#  {'_id': 'Comedy', 'count': 3275},
#  {'_id': 'Documentary', 'count': 2047},
#  {'_id': 'Comedy, Drama', 'count': 1643},
#  {'_id': 'Drama, Romance', 'count': 1392},
#  {'_id': 'Comedy, Romance', 'count': 1065},
#  {'_id': 'Comedy, Drama, Romance', 'count': 1053},
#  {'_id': 'Horror', 'count': 931},
#  {'_id': 'Crime, Drama', 'count': 626},
#  {'_id': 'Drama, Thriller', 'count': 602}]

# %% [markdown]
# #### $match

# %%
pipeline= [
    
  { '$match' : {  'year': 1990, 'genre' : 'Crime' } 
   
  } ]


pprint.pprint(list(client.cluster0.blog.aggregate(pipeline)))
# Out:
# [{'[imdbID': 2860568,
#   '_id': ObjectId('630b3ba68b423977318a96ce'),
#   'awards': '',
#   'cast': 'Aleksandr Abdulov, Donatas Banionis, Emmanuil Vitorgan',
#   'country': 'Soviet Union',
#   'director': 'Mark Aizenberg',
#   'fullplot': '',
#   'genre': 'Crime',
#   'imdbRating': '',
#   'imdbVotes': '',
#   'language': 'Russian',
#   'lastupdated': '2015-05-14 00:46:58.517000000',
#   'metacritic': '',
#   'plot': '',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '',
#   'title': 'Zhivaja mishen',
#   'type]': 'movie',
#   'writer': '',
#   'year': 1990}]

# %% [markdown]
# #### $project

# %%
mycollection.aggregate([
  { '$project' : { '_id' : 0, 'title' : 1, 'genre' : 1 } }
])

for record in mycollection.aggregate([
  { '$project' : { '_id' : 0, 'title' : 1, 'genre' : 1 } }
]):
    print(record)
# Out:
# {'title': 'Blacksmith Scene', 'genre': 'Short'}
# {'title': 'The Land Beyond the Sunset', 'genre': 'Short, Drama, Fantasy'}
# {'title': 'The Sea', 'genre': 'Documentary, Short'}
# {'title': "Dante's Inferno", 'genre': 'Adventure, Drama, Fantasy'}
# {'title': 'Carmencita', 'genre': 'Documentary, Short'}
# {'title': "Grandma's Reading Glass", 'genre': 'Short'}
# {'title': 'The Conjuring of a Woman at the House of Robert Houdin', 'genre': 'Short'}
# {'title': 'New York Subway', 'genre': 'Short, Documentary'}
# {'title': 'The Wonderful Wizard of Oz', 'genre': 'Adventure, Fantasy, Short'}
# {'title': "The Burglar's Dilemma", 'genre': 'Short, Drama'}
# {'title': 'A Beast at Bay', 'genre': 'Short, Drama'}
# {'title': 'Fantomas', 'genre': 'Crime, Drama'}
# {'title': 'Ingeborg Holm', 'genre': 'Drama'}
# {'title': "Tillie's Punctured Romance", 'genre': 'Comedy'}
# {'title': 'The Captive', 'genre': 'Drama, Romance, War'}
# {'title': 'Going Straight', 'genre': 'Crime, Drama'}
# ...

# %% [markdown]
# #### $limit

# %%
pipeline = [
    {
        '$limit': 10
    },
    {
        '$project': {
            'title': 1,
            'year': 1,
            'directors': {'$split': ["$director", ", "]},
            'actors': {'$split': ["$cast", ", "]},
            'writers': {'$split': ["$writer", ", "]},
            'genres': {'$split': ["$genre", ", "]},
            'languages': {'$split': ["$language", ", "]},
            'countries': {'$split': ["$country", ", "]},
            'plot': 1,
            'fullPlot': "$fullplot",
            'rated': "$rating",
            'released': 1,
            'runtime': 1,
            'poster': 1,
            'imdb': {
                'id': "$imdbID",
                'rating': "$imdbRating",
                'votes': "$imdbVotes"
                },
            'metacritic': 1,
            'awards': 1,
            'type': 1,
            'lastUpdated': "$lastupdated"
        }
    }
]

clear_output()
pprint.pprint(list(client.cluster0.blog.aggregate(pipeline)))
# Out:
# [{'_id': ObjectId('630b3b7c8b4239773189f24f'),
#   'actors': ['Charles Kayser', 'John Ott'],
#   'awards': '1 win.',
#   'countries': ['USA'],
#   'directors': ['William K.L. Dickson'],
#   'fullPlot': 'A stationary camera looks at a large anvil with a blacksmith '
#               'behind it and one on either side. The smith in the middle draws '
#               'a heated metal rod from the fire, places it on the anvil, and '
#               'all three begin a rhythmic hammering. After several blows, the '
#               'metal goes back in the fire. One smith pulls out a bottle of '
#               'beer, and they each take a swig. Then, out comes the glowing '
#               'metal and the hammering resumes.',
#   'genres': ['Short'],
#   'imdb': {'rating': 6.2, 'votes': 1189},
#   'languages': [''],
#   'lastUpdated': '2015-08-26 00:03:50.133000000',
#   'metacritic': '',
#   'plot': 'Three men hammer on an anvil and pass a bottle of beer around.',
#   'poster': '',
# ...

# %% [markdown]
# #### $out

# %%
pipeline = [
    {
        '$limit': 5
    },
    {
        '$project': {
            'title': 1,
            'year': 1,
            'imdb': {
                'id': "$imdbID",
                'rating': "$imdbRating",
                'votes': "$imdbVotes"
                },
            'metacritic': 1,
            'runtime':1,
        }
    },
    {
        '$out': "movie_critics"
    }
]

clear_output()
pprint.pprint(list(client.cluster0.blog.aggregate(pipeline)))
# Out:
# []

# %%
pipeline = [
    {
        '$match' : {  'year':{'$lt':1950}, 'genre' : 'Drama' } ,
    },
    {
        '$project': {
            'title': 1,
            'year': 1,
            'genres': {'$split': ["$genre", ", "]},
            'languages': {'$split': ["$language", ", "]},
            'countries': {'$split': ["$country", ", "]},
            'poster': 1,
            'imdbRating':1
    }
    },
         {'$sort': {'imdbRating': 1}
    }
]

clear_output()
pprint.pprint(list(client.cluster0.blog.aggregate(pipeline)))
# Out:
# [{'_id': ObjectId('630b3b7d8b4239773189f830'),
#   'countries': ['USA'],
#   'genres': ['Drama'],
#   'imdbRating': 3.7,
#   'languages': ['English'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTMxNzUwNzIxNF5BMl5BanBnXkFtZTcwMDE3ODU1NQ@@._V1._CR34.883331298828125,38.53334045410156,284,406_SY132_CR1,0,89,132_AL_.jpg_V1_SX300.jpg',
#   'title': 'Reefer Madness',
#   'year': 1936},
#  {'_id': ObjectId('630b3b7d8b4239773189f80a'),
#   'countries': ['USA'],
#   'genres': ['Drama'],
#   'imdbRating': 3.9,
#   'languages': ['English'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTUwMzcwODcwM15BMl5BanBnXkFtZTgwMDE1OTg5MTE@._V1_SX300.jpg',
#   'title': 'The Pace That Kills',
#   'year': 1935},
#  {'_id': ObjectId('630b3b7d8b4239773189f8f6'),
#   'countries': ['USA'],
#   'genres': ['Drama'],
#   'imdbRating': 4.5,
#   'languages': ['English'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTM4MDI5MDg1NF5BMl5BanBnXkFtZTcwNzI4NDgyMQ@@._V1_SX300.jpg',
# ...
